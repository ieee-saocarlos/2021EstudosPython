# %% [markdown]
# <a href="https://colab.research.google.com/github/AllanKamimura/2021EstudosPython/blob/main/2022/CS_IA_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href=https://colab.research.google.com/github/ieee-saocarlos/2021EstudosPython/blob/main/2022/CS_IA_00.ipynb target=_parent><img src=https://colab.research.google.com/assets/colab-badge.svg alt=Open In Colab/></a>

# %%
# conecte no seu google drive
from google.colab import drive
drive.mount('/drive')

# %% [markdown]
# # Grupo A
#
# coisas que podem ser uteis:
#
# *   os
# *   glob
# *   pandas
# *   Basic Linux Commands

# %%
# baixa os arquivos do meu google drive
# !gdown 1i2OqVW60CPNfNpO76p2khhxnZUElXflZ

# unzip into folder "mess_dataset"
# !unzip -qq /content/mess_dataset.zip

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### quantos arquivos tem ao todo?

# %% [markdown]
# ### quantas images de cada pokemon tem? / qual a media de imagens por pokemon?

# %% [markdown]
# ### Algum pokemon tem muito mais imagens do que outros? / Tem algum pokemon faltando?

# %% [markdown]
# ## Arrumando o dataset

# %% [markdown]
# ### Caminho 1: Diretorios e subdiretoris
#
# ```
# ── [dataset]
#         ├── pokemon_1
#         │     ├── image1.png
#         │     ├── image2.png
#         │     └──  ...
#         ├── pokemon_2
#         │    ├── image1.png
#         │    ├── image2.png
#         │    └──  ...
#        ...
# ```

# %% [markdown]
# ### Caminho 2: DataFrame
#
# |    filename    |  class  |
# |:--------------:|:-------:|
# |path_to_image_1 |pokemon_1|
# |path_to_image_2 |pokemon_2|
# |path_to_image_3 |pokemon_3|
# |path_to_image_4 |pokemon_4|
# |path_to_image_5 |pokemon_5|

# %% [markdown]
# ## Testando

# %% [markdown]
# ### Caminho 1

# %%
dataset_path = "Escrever o path aqui"

import tensorflow as tf

datagen = tf.keras.preprocessing.image.ImageDataGenerator()
x = datagen.flow_from_directory(dataset_path)

# resultado esperado: 
# "Found xxxx images belonging to yyy classes."

# %% [markdown]
# ### Caminho 2

# %%
# dataset_dataframe = seu_df

import tensorflow as tf

datagen = tf.keras.preprocessing.image.ImageDataGenerator()
x = datagen.flow_from_dataframe(
    dataset_dataframe,
    directory = "./mess_dataset",
    validate_filenames = False)

# resultado esperado: 
# "Found xxxx images belonging to yyy classes."

# %% [markdown]
# # Grupo B
#
# coisas que podem ser uteis:
#
# *   os
# *   re
# *   PIL
# *   glob
# *   requests
# *   Beautiful Soup
# *   matplotlib.pyplot

# %% [markdown]
# site base
#
# https://www.serebii.net/pokedex/
#
# pokedex base
#
# upar a imagem do Discord

# %% [markdown]
# ## Baixar imagens para pokedex

# %% [markdown]
# ## Baixar informações para a pokedex

# %% [markdown]
# ## Plotar as informações e verificar se estão corretas
#
# (isso será util mais tarde)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Adicionar as informações na pokedex

# %% [markdown]
# ![image.png](data:image/png;base64,...)
